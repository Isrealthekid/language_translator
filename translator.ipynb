# %%
pip install torch==1.8.1+cpu torchvision==0.9.1+cpu torchaudio==0.8.1 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement torch==1.8.1+cpu (from versions: 2.0.0, 2.0.0+cpu, 2.0.0+cu117, 2.0.0+cu118, 2.0.1, 2.0.1+cpu, 2.0.1+cu117, 2.0.1+cu118, 2.1.0, 2.1.0+cpu, 2.1.0+cu118, 2.1.0+cu121, 2.1.1, 2.1.1+cpu, 2.1.1+cu118, 2.1.1+cu121, 2.1.2, 2.1.2+cpu, 2.1.2+cu118, 2.1.2+cu121, 2.2.0, 2.2.0+cpu, 2.2.0+cu118, 2.2.0+cu121, 2.2.1, 2.2.1+cpu, 2.2.1+cu118, 2.2.1+cu121, 2.2.2, 2.2.2+cpu, 2.2.2+cu118, 2.2.2+cu121, 2.3.0, 2.3.0+cpu, 2.3.0+cu118, 2.3.0+cu121)
# ERROR: No matching distribution found for torch==1.8.1+cpu

# %%
pip install torch torchvision torchaudio
# Out:
# ...
#   Using cached torch-2.3.0-cp311-cp311-win_amd64.whl.metadata (26 kB)
# ...
#   Using cached torchvision-0.18.0-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached torchaudio-2.3.0-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# ...
#   Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# ...
#   Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.2 kB)
# ...
#   Using cached tbb-2021.12.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# ...
#    ---------------------------------------- 0.0/159.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/159.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/159.8 MB 162.5 kB/s eta 0:16:24
#    ---------------------------------------- 0.0/159.8 MB 162.5 kB/s eta 0:16:24
#    ---------------------------------------- 0.0/159.8 MB 119.1 kB/s eta 0:22:22
#    ---------------------------------------- 0.0/159.8 MB 119.1 kB/s eta 0:22:22
# ...

# %%
pip install transformers ipwidgets gradio --upgrade
# Out:
# ...
#      ---------------------------------------- 0.0/138.0 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/138.0 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/138.0 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/138.0 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/138.0 kB ? eta -:--:--
#      -------- ---------------------------- 30.7/138.0 kB 109.5 kB/s eta 0:00:01
#      -------- ---------------------------- 30.7/138.0 kB 109.5 kB/s eta 0:00:01
#      -------- ---------------------------- 30.7/138.0 kB 109.5 kB/s eta 0:00:01
#      ----------- -------------------------- 41.0/138.0 kB 93.7 kB/s eta 0:00:02
#      ------------------- ----------------- 71.7/138.0 kB 163.8 kB/s eta 0:00:01
#      ------------------- ----------------- 71.7/138.0 kB 163.8 kB/s eta 0:00:01
#      ------------------------ ------------ 92.2/138.0 kB 163.8 kB/s eta 0:00:01
# ...

# %%
pip install transformers ipywidgets gradio --upgrade
# Out:
# ...
#   Using cached transformers-4.40.2-py3-none-any.whl.metadata (137 kB)
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/50.9 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.9 kB ? eta -:--:--
#      ---------------------- --------------- 30.7/50.9 kB 660.6 kB/s eta 0:00:01
#      ------------------------------ ------- 41.0/50.9 kB 393.8 kB/s eta 0:00:01
#      -------------------------------------- 50.9/50.9 kB 325.6 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/107.3 kB ? eta -:--:--
#      ---------- -------------------------- 30.7/107.3 kB 640.0 kB/s eta 0:00:01
#      -------------- ---------------------- 41.0/107.3 kB 653.6 kB/s eta 0:00:01
#      -------------- ---------------------- 41.0/107.3 kB 653.6 kB/s eta 0:00:01
#      -------------- ---------------------- 41.0/107.3 kB 653.6 kB/s eta 0:00:01
# ...

# %%
pip install tf-keras
# Out:
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.7 MB 81.9 kB/s eta 0:00:21
#    - -------------------------------------- 0.1/1.7 MB 156.1 kB/s eta 0:00:11
#    - -------------------------------------- 0.1/1.7 MB 156.1 kB/s eta 0:00:11
#    - -------------------------------------- 0.1/1.7 MB 157.1 kB/s eta 0:00:11
#    - -------------------------------------- 0.1/1.7 MB 157.1 kB/s eta 0:00:11
#    -- ------------------------------------- 0.1/1.7 MB 190.4 kB/s eta 0:00:09
# ...

# %%
import gradio as gr
from transformers import pipeline

# %%
translation_pipeline = pipeline("translation_en_to_de") #english to german
# Out:
# No model was supplied, defaulted to google-t5/t5-base and revision 686f1db (https://huggingface.co/google-t5/t5-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# C:\Users\User\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# WARNING:tensorflow:From C:\Users\User\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
results = translation_pipeline("i love ice cream")

# %%
results[0]['translation_text']
# Out:
# 'Ich liebe Eiscreme'

# %%
def translate_transformers(from_text):
    results = translation_pipeline(from_text)
    return results[0]['translation_text']

# %%
translate_transformers('My name is Isreal')
# Out:
# 'Mein Name ist Isreal'

# %%
interface = gr.Interface(fn=translate_transformers, 
                         inputs=gr.Textbox(lines=2, placeholder='Text to translate'), 
                         outputs='text')

# %%
gr.interface??
# Out:
# Type:        module
# String form: <module 'gradio.interface' from 'C:\\Users\\User\\anaconda3\\Lib\\site-packages\\gradio\\interface.py'>
# File:        c:\users\user\anaconda3\lib\site-packages\gradio\interface.py
# Source:
# """
# This file defines two useful high-level abstractions to build Gradio apps: Interface and TabbedInterface.
# """
#
# from __future__ import annotations
#
# import inspect
# import json
# import os
# import warnings
# import weakref
# from typing import TYPE_CHECKING, Any, Callable, Literal
#
# from gradio_client.documentation import document
#
# from gradio import Examples, utils, wasm_utils
# from gradio.blocks import Blocks
# from gradio.components import (
#     Button,
#     ClearButton,
#     Component,
#     DuplicateButton,
#     Markdown,
#     State,
#     get_component_instance,
# )
# from gradio.data_classes import InterfaceTypes
# from gradio.events import Dependency, Events, on
# from gradio.exceptions import RenderError
# ...

# %%
interface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
